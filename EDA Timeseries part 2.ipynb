# %%
import pandas as pd
import pandas_datareader as pdr
from datetime import datetime

# %%
df_tesla=pdr.get_data_yahoo('TSLA')

# %%
df_tesla
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-08-21   69.164001   66.370003   69.164001   67.571999  32477000.0
# 2017-08-22   68.447998   67.473999   68.225998   68.269997  21610000.0
# 2017-08-23   70.697998   67.660004   67.797997   70.554001  24772500.0
# 2017-08-24   71.332001   69.947998   70.503998   70.585999  22923500.0
# 2017-08-25   71.138000   69.459999   70.848000   69.610001  17420000.0
# ...                ...         ...         ...         ...         ...
# 2022-08-15  939.400024  903.690002  905.359985  927.960022  29786400.0
# 2022-08-16  944.000000  908.650024  935.000000  919.690002  29378800.0
# 2022-08-17  928.969971  900.099976  910.190002  911.989990  22922000.0
# 2022-08-18  919.500000  905.559998  918.000000  908.609985  15833500.0
# 2022-08-19  901.080017  877.500000  897.000000  890.000000  20417900.0
#
#              Adj Close
# Date
# 2017-08-21   67.571999
# 2017-08-22   68.269997
# 2017-08-23   70.554001
# ...

# %%
#simple moving average.it's used for smothness of graph
df_tesla['Open'].plot()
df_tesla['Open'].rolling(10,1).mean().plot(xlim=['2020-01-01','2021-01-01'],color='red',figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open'].rolling(window=5,min_periods=2).mean().head(10)
# Out:
# Date
# 2017-08-21          NaN
# 2017-08-22    68.695000
# 2017-08-23    68.395999
# 2017-08-24    68.922998
# 2017-08-25    69.307999
# 2017-08-28    69.366399
# 2017-08-29    69.300400
# 2017-08-30    69.727600
# 2017-08-31    69.768800
# 2017-09-01    69.844000
# Name: Open, dtype: float64

# %%
##commulating moving avg using expanding
df_tesla['Open'].plot()
df_tesla['Open'].expanding().mean().plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##EWMA-- Exponentail
